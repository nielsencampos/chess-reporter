# %%
input_game_str: str = """
[Event "Live Chess"]
[Site "Chess.com"]
[Date "2026.02.23"]
[Round "-"]
[White "Smothered_mate1964"]
[Black "nielsenmendescampos"]
[Result "1-0"]
[CurrentPosition "rn1qkb1r/pp2pBpp/2p2n2/4N3/3P4/2N5/PPP3PP/R1BbK2R b KQkq - 0 8"]
[Timezone "UTC"]
[ECO "B15"]
[ECOUrl "https://www.chess.com/openings/Caro-Kann-Defense-von-Hennig-Gambit"]
[UTCDate "2026.02.23"]
[UTCTime "17:19:24"]
[WhiteElo "1103"]
[BlackElo "1067"]
[TimeControl "180"]
[Termination "Smothered_mate1964 won by checkmate"]
[StartTime "17:19:24"]
[EndDate "2026.02.23"]
[EndTime "17:19:43"]
[Link "https://www.chess.com/analysis/game/live/165106586944/analysis"]
[WhiteUrl "https://www.chess.com/bundles/web/images/noavatar_l.84a92436.gif"]
[WhiteCountry "2"]
[WhiteTitle ""]
[BlackUrl "https://images.chesscomfiles.com/uploads/v1/user/145760667.d645313d.50x50o.7374f87d431b.png"]
[BlackCountry "27"]
[BlackTitle ""]

1. e4 {[%clk 0:02:59.9]} 1... c6 {[%clk 0:02:58.7]} 2. d4 {[%clk 0:02:58.8]}
2... d5 {[%clk 0:02:58.6]} 3. Nc3 {[%clk 0:02:58.3]} 3... dxe4 {[%clk
0:02:55.9]} 4. Bc4 {[%clk 0:02:57.6]} 4... Nf6 {[%clk 0:02:52.3]} 5. f3 {[%clk
0:02:57.1]} 5... exf3 {[%clk 0:02:51]} 6. Nxf3 {[%clk 0:02:57]} 6... Bg4 {[%clk
0:02:49.8]} 7. Ne5 {[%clk 0:02:56.4]} 7... Bxd1 {[%clk 0:02:47.4]} 8. Bxf7#
{[%clk 0:02:55.6][%c_effect
e1;square;e1;type;Winner;animated;true,e8;square;e8;type;CheckmateBlack;animated;true]}
1-0
"""

# %%
input_game_str: str = """
[Event "Live Chess"]
[Site "Chess.com"]
[Date "2026.02.20"]
[Round "-"]
[White "nielsenmendescampos"]
[Black "hiperhidra603"]
[Result "1/2-1/2"]
[CurrentPosition "6k1/6P1/6K1/8/8/8/8/8 b - - 2 65"]
[Timezone "UTC"]
[ECO "A04"]
[ECOUrl "https://www.chess.com/openings/Reti-Opening-Kingside-Fianchetto-Variation-2.g3-Bg7-3.d4"]
[UTCDate "2026.02.20"]
[UTCTime "19:16:53"]
[WhiteElo "1232"]
[BlackElo "1230"]
[TimeControl "600"]
[Termination "Game drawn by stalemate"]
[StartTime "19:16:53"]
[EndDate "2026.02.20"]
[EndTime "19:31:50"]
[Link "https://www.chess.com/analysis/game/live/164973965638/analysis"]
[WhiteUrl "https://images.chesscomfiles.com/uploads/v1/user/145760667.d645313d.50x50o.7374f87d431b.png"]
[WhiteCountry "27"]
[WhiteTitle ""]
[BlackUrl "https://images.chesscomfiles.com/uploads/v1/user/167973295.7f23889e.50x50o.afec0a4ca766.jpeg"]
[BlackCountry "69"]
[BlackTitle ""]

[Round "-"]
[White "Anonymous"]
[Black "Anonymous"]
[Result "1-0"]
[GameId "OH7Be7RS"]
[UTCDate "2026.02.25"]
[UTCTime "19:03:46"]
[WhiteElo "?"]
[BlackElo "?"]
[Variant "Standard"]
[TimeControl "180+0"]
[ECO "A45"]
[Opening "Indian Defense: Accelerated London System"]
[Termination "Normal"]
[Annotator "lichess.org"]

1. d4 Nf6 2. Bf4 { A45 Indian Defense: Accelerated London System } g6 3. e3 Bg7 4. Bd3 O-O 5. c3 d5 6. Qc2 c6 7. h3 Nbd7 8. Bh2 Nb6 9. f4 Ne4 10. Nd2 Bf5 11. g4 Nxd2 12. Bxf5 Nbc4 13. Bd3 Qc7 14. b3 Na3 15. Qxd2 e5 16. Qb2 f5 17. Qxa3 e4 18. Be2 fxg4 19. Bxg4 h5 20. Be2 Qb6 21. O-O-O { Black resigns. } 1-0
"""

# %%
input_game_str: str = """

[Event "Live Chess"]
[Site "Chess.com"]
[Date "2026.02.25"]
[Round "-"]
[White "nielsenmendescampos"]
[Black "TheDarkKnightj316"]
[Result "1-0"]
[CurrentPosition "2r1r1k1/p1q2ppp/2p5/5p2/5B2/6P1/PP3PBP/R2QR1K1 w - - 0 20"]
[Timezone "UTC"]
[ECO "D02"]
[ECOUrl "https://www.chess.com/openings/Queens-Pawn-Opening-Krause-Variation-3.c3-Nc6"]
[UTCDate "2026.02.25"]
[UTCTime "18:43:51"]
[WhiteElo "1029"]
[BlackElo "1018"]
[TimeControl "180"]
[Termination "nielsenmendescampos won by resignation"]
[StartTime "18:43:51"]
[EndDate "2026.02.25"]
[EndTime "18:45:39"]
[Link "https://www.chess.com/analysis/game/live/165202585552/analysis"]
[WhiteUrl "https://images.chesscomfiles.com/uploads/v1/user/145760667.d645313d.50x50o.7374f87d431b.png"]
[WhiteCountry "27"]
[WhiteTitle ""]
[BlackUrl "https://images.chesscomfiles.com/uploads/v1/user/98987204.969ed485.50x50o.9ed4cfe02e0b.jpg"]
[BlackCountry "2"]
[BlackTitle ""]

1. d4 {[%clk 0:02:56.6]} 1... d5 {[%clk 0:02:59.3]} 2. Nf3 {[%clk 0:02:51.2]}
2... c5 {[%clk 0:02:58]} 3. c3 {[%clk 0:02:49.7]} 3... Nc6 {[%clk 0:02:55.8]} 4.
e3 {[%clk 0:02:46.3]} 4... e6 {[%clk 0:02:53.7]} 5. g3 {[%clk 0:02:44.9]} 5...
Bd6 {[%clk 0:02:52.9]} 6. Bg2 {[%clk 0:02:44.8]} 6... Bd7 {[%clk 0:02:51.6]} 7.
O-O {[%clk 0:02:44.3]} 7... Nge7 {[%clk 0:02:51.1]} 8. Re1 {[%clk 0:02:43.7]}
8... O-O {[%clk 0:02:50.4]} 9. Nbd2 {[%clk 0:02:43]} 9... Qc7 {[%clk 0:02:49.4]}
10. e4 {[%clk 0:02:41.3]} 10... Rfe8 $4 {[%clk 0:02:40.4][%c_effect
e8;square;e8;type;Blunder;persistent;true]} 11. e5 $1 {[%clk 0:02:40.3][%c_effect
e5;square;e5;type;GreatFind;persistent;true]} 11... Nxe5 $6 {[%clk
0:02:36.9][%c_effect e5;square;e5;type;Inaccuracy;persistent;true]} 12. dxe5
{[%clk 0:02:37.3]} 12... Bxe5 {[%clk 0:02:35.2]} 13. Nxe5 {[%clk 0:02:36]} 13...
d4 {[%clk 0:02:29.3]} 14. cxd4 {[%clk 0:02:31.1]} 14... cxd4 {[%clk 0:02:28.4]}
15. Ndf3 {[%clk 0:02:26.4]} 15... Rac8 {[%clk 0:02:23]} 16. Nxd4 {[%clk
0:02:22.2]} 16... Nf5 {[%clk 0:02:20.8]} 17. Nxf5 {[%clk 0:02:20.7]} 17... exf5
{[%clk 0:02:19.6]} 18. Bf4 {[%clk 0:02:14.9]} 18... Bc6 $6 {[%clk
0:02:09.4][%c_effect c6;square;c6;type;Inaccuracy;persistent;true]} 19. Nxc6
{[%clk 0:02:13.7]} 19... bxc6 {[%clk 0:02:08][%c_effect
g1;square;g1;type;Winner;animated;true,g8;square;g8;type;ResignBlack;animated;true]}
1-0
"""

# %%
input_game_str: str = """
[Event "rated blitz game"]
[Site "https://lichess.org/iuIjdeYr"]
[Date "2026.03.12"]
[Round "-"]
[White "Pyke333"]
[Black "nielsencampos"]
[Result "0-1"]
[GameId "iuIjdeYr"]
[UTCDate "2026.03.12"]
[UTCTime "20:23:49"]
[WhiteElo "1435"]
[BlackElo "1441"]
[WhiteRatingDiff "-5"]
[BlackRatingDiff "+75"]
[Variant "Standard"]
[TimeControl "180+0"]
[ECO "A45"]
[Opening "Trompowsky Attack"]
[Termination "Normal"]
[Annotator "lichess.org"]

1. d4 { [%eval 0.15] [%clk 0:03:00] } 1... Nf6 { [%eval 0.15] [%clk 0:03:00] } 2. Bg5 { [%eval 0.0] [%clk 0:02:58] } { A45 Trompowsky Attack } 2... h6 { [%eval 0.2] [%clk 0:02:55] } 3. Bh4 { [%eval 0.0] [%clk 0:02:57] } 3... g5 { [%eval 0.08] [%clk 0:02:53] } 4. Bg3 { [%eval 0.0] [%clk 0:02:56] } 4... d5 { [%eval 0.15] [%clk 0:02:51] } 5. e3 { [%eval 0.15] [%clk 0:02:54] } 5... Bg7 { [%eval 0.13] [%clk 0:02:51] } 6. Nc3 { [%eval 0.08] [%clk 0:02:52] } 6... Bf5 { [%eval 0.54] [%clk 0:02:49] } 7. Bd3 { [%eval 0.4] [%clk 0:02:50] } 7... Bg6? { (0.40 → 1.70) Mistake. Ne4 was best. } { [%eval 1.7] [%clk 0:02:46] } (7... Ne4 8. Bxe4 dxe4 9. f3 c5 10. fxe4 Bg6 11. Nf3 cxd4 12. exd4) 8. Bxg6 { [%eval 1.67] [%clk 0:02:48] } 8... fxg6 { [%eval 1.68] [%clk 0:02:46] } 9. Nf3 { [%eval 1.8] [%clk 0:02:44] } 9... Qd7 { [%eval 2.04] [%clk 0:02:45] } 10. Ne5 { [%eval 2.0] [%clk 0:02:43] } 10... Qe6?! { (2.00 → 2.96) Inaccuracy. Qf5 was best. } { [%eval 2.96] [%clk 0:02:45] } (10... Qf5 11. Qd3 Qxd3 12. cxd3 c6 13. Nxg6 Rg8 14. h4 Ng4 15. hxg5 hxg5 16. Ne5) 11. Nxg6 { [%eval 2.38] [%clk 0:02:39] } 11... Rg8 { [%eval 2.18] [%clk 0:02:43] } 12. Ne5 { [%eval 2.15] [%clk 0:02:37] } 12... Nc6?! { (2.15 → 3.20) Inaccuracy. c6 was best. } { [%eval 3.2] [%clk 0:02:40] } (12... c6 13. a4 Na6 14. h4 O-O-O 15. hxg5 hxg5 16. Qe2 Nb4 17. O-O-O Rh8 18. Rxh8) 13. Nxc6?! { (3.20 → 1.89) Inaccuracy. Nb5 was best. } { [%eval 1.89] [%clk 0:02:35] } (13. Nb5 Kd8 14. Nd3 Qf5 15. Nxc7 Rc8 16. Qf3 e6 17. Qxf5 exf5 18. Ne6+ Ke7) 13... Qxc6 { [%eval 2.06] [%clk 0:02:40] } 14. Qd3 { [%eval 2.06] [%clk 0:02:33] } 14... O-O-O?! { (2.06 → 2.75) Inaccuracy. a6 was best. } { [%eval 2.75] [%clk 0:02:39] } (14... a6 15. Qg6+ Kd7 16. h4 gxh4 17. Rxh4 Raf8 18. O-O-O Kc8 19. a3 e6 20. Kb1) 15. O-O-O?! { (2.75 → 1.60) Inaccuracy. Nb5 was best. } { [%eval 1.6] [%clk 0:02:28] } (15. Nb5 Kd7 16. Nxa7 Qc4 17. Qxc4 dxc4 18. Nb5 c6 19. Nc3 Ra8 20. Ke2 b5) 15... e6? { (1.60 → 2.92) Mistake. a6 was best. } { [%eval 2.92] [%clk 0:02:38] } (15... a6 16. h4 g4 17. Kb1 Kb8 18. a3 Nh5 19. Bh2 Bh8 20. Qf5 Nf6 21. f3) 16. e4?? { (2.92 → 0.12) Blunder. Nb5 was best. } { [%eval 0.12] [%clk 0:02:21] } (16. Nb5 Qa6 17. Nxc7 Qxa2 18. Nxe6 Ne4 19. c3 Rd7 20. f3 Nxg3 21. hxg3 Bf8) 16... dxe4?! { (0.12 → 0.92) Inaccuracy. Nxe4 was best. } { [%eval 0.92] [%clk 0:02:34] } (16... Nxe4 17. Nxe4 dxe4 18. Qe3 Qd5 19. c3 h5 20. h3 h4 21. Bh2 Rdf8 22. Kb1) 17. Qe3?! { (0.92 → 0.06) Inaccuracy. Qb5 was best. } { [%eval 0.06] [%clk 0:02:10] } (17. Qb5 Qxb5 18. Nxb5 Nd5 19. Nxa7+ Kb8 20. Nb5 h5 21. Rhe1 Rdf8 22. Rd2 h4) 17... Nd5 { [%eval -0.03] [%clk 0:02:30] } 18. Nxe4?? { (-0.03 → -6.24) Blunder. Qxe4 was best. } { [%eval -6.24] [%clk 0:02:04] } (18. Qxe4 Nxc3 19. Qxc6 Nxa2+ 20. Kb1 bxc6 21. Kxa2 Bxd4 22. Rhe1 h5 23. Rxe6 h4) 18... Nxe3 { [%eval -6.42] [%clk 0:02:28] } 19. fxe3 { [%eval -6.24] [%clk 0:02:01] } 19... Qxe4 { [%eval -6.19] [%clk 0:02:24] } { White resigns. } 0-1
"""

# %%
input_game_str: str = "1. e4 Nc6 2. Nf3 Nf6 3. e5 Ng4 4. d4 d6 5. h3 Nh6 6. e6 *"

# %%
from io import StringIO

from chess import Board, Move
from chess.pgn import Game, GameNode, StringExporter, read_game

# %%
source_game: Game = read_game(StringIO(input_game_str))
source_game_node: GameNode = source_game
target_game: Game = Game()
target_game_node: GameNode = target_game
board: Board = source_game_node.board().copy(stack=False)
board_str: str = str(board)
move_number: int = board.fullmove_number

# %%
from chess_reporter.domain.position import PositionContext

# %%
from chess_reporter.engine import EngineManager

# %%
position: PositionContext = PositionContext(board=board)

# %%
engine: EngineManager = EngineManager(context=position)
# Out:
# 2026-03-17 03:50:05 | INFO     | chess_reporter.engine.engine_manager:96 - Engine config data:
# {'name_version': 'Stockfish 18', 'threads': 4, 'hash_table_mb': 2048, 'depth': 30, 'multipv': 7, 'analyses': 7, 'parallelism': True, 'status': <DataStatus.COMPLETED: 'completed'>, 'id': '13232c92f5226e2d3b36ee97b1fce57e90217a9ad43b693619148a49875990f44c39741092f78d589e8dc1e90685e7e34930b1b92136fb1c8fa7b6edf0ffda17'}

# %%
results = engine.analyze()

# %%
from pandas import DataFrame

# %%
dataframe = DataFrame([
    {
        "analysis_run": row.analysis_run,
        "variation_rank": row.variation_rank,
        "evaluation": row.evaluation,
        "search_depth": row.search_depth,
        "selective_search_depth": row.selective_search_depth,
        "hash_table_usage": row.hash_table_usage,
        "time_in_seconds": row.time_in_seconds,
        "started_analysis_at": row.started_analysis_at,
        "finished_analysis_at": row.finished_analysis_at,
    }
    for row in results])

# %%
dataframe
# Out:
#     analysis_run  variation_rank evaluation  search_depth  \
# 0              1               1      +0.92            30
# 1              1               2      +1.64            30
# 2              1               3      +2.04            30
# 3              1               4      +2.18            30
# 4              1               5      +2.44            30
# 5              1               6      +2.83            30
# 6              1               7      +3.14            30
# 7              2               1      +0.93            30
# 8              2               2      +1.74            30
# 9              2               3      +2.12            30
# 10             2               4      +2.12            30
# 11             2               5      +2.39            30
# 12             2               6      +2.88            30
# 13             2               7      +3.15            30
# 14             3               1      +0.85            30
# ...

# %%
dataframe[dataframe["variation_rank"] == 1]
# Out:
#     analysis_run  variation_rank evaluation  search_depth  \
# 0              1               1      +0.92            30
# 7              2               1      +0.93            30
# 14             3               1      +0.85            30
# 21             4               1      +0.94            30
# 28             6               1      +0.83            30
# 35             5               1      +0.93            30
# 42             7               1      +0.91            30
#
#     selective_search_depth  hash_table_usage  time_in_seconds  \
# 0                       40              73.7         0.297240
# 7                       53              83.5         0.389682
# 14                      58              85.4         0.418260
# 21                      54              85.8         0.424751
# 28                      52              72.7         0.324429
# 35                      56              79.7         0.380922
# 42                      57              83.2         0.244392
# ...

# %%
results[0]
# Out:
# EngineAnalysis(context=EngineContext(position_context=PositionContext(board=Board('r1bqkb1r/ppp1pppp/2npP2n/8/3P4/5N1P/PPP2PP1/RNBQKB1R b KQkq - 0 6'), game_outcome_input=None, fen='r1bqkb1r/ppp1pppp/2npP2n/8/3P4/5N1P/PPP2PP1/RNBQKB1R b KQkq - 0 6', chess960=False, ascii_board='r . b q k b . r\np p p . p p p p\n. . n p P . . n\n. . . . . . . .\n. . . P . . . .\n. . . . . N . P\nP P P . . P P .\nR N B Q K B . R', game_termination=<GameTermination.ONGOING: 'ongoing'>, game_result=<GameResult.ONGOING: 'ongoing'>, turn=<PositionTurn.BLACK: 'black'>, white_material=3900, white_piece_count=16, black_material=3900, black_piece_count=16, overall_material=7800, overall_piece_count=32, material_balance=0, piece_count_balance=0, material_game_phase=<GamePhase.OPENING: 'opening'>, legal_moves_count=23, captures_count=3), analysis_run=1), started_analysis_at=datetime.datetime(2026, 3, 17, 3, 50, 7, 897947, tzinfo=datetime.timezone.utc), finished_analysis_at=datetime.datetime(2026, 3, 17, 3, 55, 5
# ...

# %%
source_game_node = source_game_node.next()
move_text_string_exporter: StringExporter = StringExporter(headers=False, variations=False, comments=False)
move_text: str = ""

# %%
while True:
    move: Move = source_game_node.move
    move_ply: int = source_game_node.ply()
    move_uci: str = source_game_node.uci()
    move_san: str = source_game_node.san()
    move_comment: str = source_game_node.comment
    target_game_node = target_game_node.add_main_variation(move)
    move_text = target_game_node.accept(move_text_string_exporter).strip()
    source_game_node = source_game_node.next()
    #print(f" * board:\n{str(board)}")
    print(f" * move_number: {move_number}")
    print(f" * move_ply: {move_ply}")
    print(f" * move_uci: {move_uci}")
    print(f" * move_comment: {move_comment}")
    print(f" * move_text: {move_text}")
    print("")
    
    if source_game_node is None:
        break

    board = source_game_node.board().copy(stack=False)
    board_str = str(board)
    move_number = board.fullmove_number
# Out:
#  * move_number: 1
#  * move_ply: 1
#  * move_uci: e2e4
#  * move_comment:
#  * move_text: 1. e4
#
#  * move_number: 2
#  * move_ply: 2
#  * move_uci: b8c6
#  * move_comment:
#  * move_text: 1. e4 Nc6
#
#  * move_number: 2
#  * move_ply: 3
#  * move_uci: g1f3
#  * move_comment:
#  * move_text: 1. e4 Nc6 2. Nf3
#
#  * move_number: 3
#  * move_ply: 4
#  * move_uci: g8f6
#  * move_comment:
#  * move_text: 1. e4 Nc6 2. Nf3 Nf6
#
#  * move_number: 3
#  * move_ply: 5
#  * move_uci: e4e5
#  * move_comment:
#  * move_text: 1. e4 Nc6 2. Nf3 Nf6 3. e5
#
#  * move_number: 4
#  * move_ply: 6
#  * move_uci: f6g4
#  * move_comment:
#  * move_text: 1. e4 Nc6 2. Nf3 Nf6 3. e5 Ng4
#
#  * move_number: 4
#  * move_ply: 7
#  * move_uci: d2d4
#  * move_comment:
#  * move_text: 1. e4 Nc6 2. Nf3 Nf6 3. e5 Ng4 4. d4
#
#  * move_number: 5
#  * move_ply: 8
#  * move_uci: d7d6
#  * move_comment:
#  * move_text: 1. e4 Nc6 2. Nf3 Nf6 3. e5 Ng4 4. d4 d6
#
#  * move_number: 5
#  * move_ply: 9
#  * move_uci: h2h3
# ...
